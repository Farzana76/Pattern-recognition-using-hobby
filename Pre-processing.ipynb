# %%
import pandas as pd

df = pd.read_excel (r'I:\Pattern Lab\dataset\EXTENDED_1.xlsx') #for an earlier version of Excel, you may need to use the file extension of 'xls'
df.head()
# Out:
#             Timestamp  Score         ID  Gender   Height  Weight  CGPA  \
# 0  3/23/2019 19:10:21  0 / 2  151341004     NaN      5.7     NaN   NaN
# 1  3/24/2019 14:29:31  0 / 1  151341021    Male     5'3"    61.0  3.48
# 2  3/24/2019 14:33:11  0 / 1  151341012    Male      5.8    78.0  2.90
# 3  3/24/2019 14:34:00  0 / 1  151341008  Female      5.3    48.0  3.33
# 4  3/24/2019 14:33:55  0 / 1  151341011    Male  161.544    59.0  3.72
#
#   Daily spent time in social media (hour)     Hometown  \
# 0                                     NaN          NaN
# 1                     2019-05-02 00:00:00   Lakshmipur
# 2                            Below 1 hour   Munshiganj
# 3                     2019-05-02 00:00:00     Bagerhat
# 4                     2019-05-02 00:00:00  kishoregonj
#
#   How many days in a week you feel more energetic  \
# 0                                             NaN
# 1                                               4
# ...

# %%
data1 = pd.read_excel (r'I:\Pattern Lab\dataset\DATASET_1.xlsx') #for an earlier version of Excel, you may need to use the file extension of 'xls'
data1.head()
# Out:
#             ID Current Place Unnamed: 2 Unnamed: 3 Place of interest  \
# 0          NaN    Place Name   Latitude  Longitude        Place Name
# 1  151340976.0         Goran    23.7503    90.4341       Cox's Bazar
# 2  151340977.0      Banasree    22.5135    88.3015         Sea Beach
# 3  151340978.0       Azimpur     23.727    90.3847       Kaptai Lake
# 4  151340980.0       Niketon    23.7073    90.4155              home
#
#   Unnamed: 5 Unnamed: 6 Food you like most Leisure time activity  \
# 0   Latitude  Longitude                NaN                   NaN
# 1    21.4113    91.9959           Biriyani                Movies
# 2        NaN        NaN            Kachchi                Sports
# 3    22.7552     92.277     kacchi biryani                Series
# 4    23.7073    90.4155                any          movies,music
#
#                      Future plan Typically your days are started at:
# 0                            NaN                                 NaN
# ...

# %%
data2 = pd.read_excel (r'I:\Pattern Lab\dataset\DATASET_2.xlsx') #for an earlier version of Excel, you may need to use the file extension of 'xls'
data2.head()
# Out:
#             ID Current Place Unnamed: 2 Unnamed: 3 Place of interest  \
# 0          NaN          Name   Latitude  Longitude              Name
# 1  151340894.0        Mirpur    23.7766     90.383      Saint Martin
# 2  151340897.0     Mohanogor    23.7346     90.385            Canada
# 3  151340898.0       Gopibag    23.7221    90.4262         Bandarban
# 4  151340900.0       Rampura    23.7612    90.4208            Norway
#
#   Unnamed: 5 Unnamed: 6 Food you like most  Leisure time activity  \
# 0   Latitude  Longitude                NaN                    NaN
# 1    20.6233     92.323           Biriyani        listening music
# 2    56.1304   -106.347       Egg and Milk     Reading Newspapers
# 3   -7.73352    112.959                Tea  ChitChat with friends
# 4      22.32    39.1008              Hilsa      Reading Magazines
#
#     Future plan Typically your days are started at:
# 0           NaN                                 NaN
# ...

# %%
data3 = pd.read_excel (r'I:\Pattern Lab\dataset\DATASET_3.xlsx') #for an earlier version of Excel, you may need to use the file extension of 'xls'
data3.head()
# Out:
#             ID Current Place Unnamed: 2 Unnamed: 3 Place of Interest  \
# 0          NaN    Place Name   Latitude  Longitude        Place Name
# 1  151340949.0      kunipara    20.5383    86.3094         Bandarban
# 2  151340950.0      Khilgaon    23.7073    90.4155         Bandarban
# 3  151340951.0      Matikata    23.8225    90.3935         Bandarban
# 4  151340952.0      Banasree    23.7632    90.4348      Saint Martin
#
#   Unnamed: 5 Unnamed: 6 Food you like most Leisure time Activity  \
# 0   Latitude  Longitude                NaN                   NaN
# 1    21.8311    92.3686          coldcoffe   Music,reading Quran
# 2    21.8311    92.3686              Kabab       Watching movies
# 3    21.8311    92.3686     Kacchi Biriany       Watching movies
# 4    20.9232    92.2676      Fish Barbecue               Jogging
#
#          Future Plan Typically your days are started at:
# 0                NaN                                 NaN
# ...

# %%
data4 = pd.read_excel (r'I:\Pattern Lab\dataset\DATASET_4.xlsx') #for an earlier version of Excel, you may need to use the file extension of 'xls'
data4.head()
# Out:
#             ID Current Place Unnamed: 2 Unnamed: 3 Place of interest  \
# 0          NaN          Name   Latitude  Longitude              Name
# 1  151341035.0    Green Road    46.0912   -67.7555            Madrid
# 2  121440946.0        Mirpur    23.8381    90.3645          New York
# 3  151341042.0      Modhubag    23.7512     90.409             Kaaba
# 4  151341043.0   Siddheswari    23.7073    90.4155          New York
#
#   Unnamed: 5 Unnamed: 6 Food you like most Leisure time activity   \
# 0   Latitude  Longitude                NaN                    NaN
# 1    40.4168   -3.70379   Nothing Specific          Playing Games
# 2    40.7128    -74.006   Nothing Specific        Listening songs
# 3    21.4225    39.8262             Orange         Watching Movie
# 4    40.7128    -74.006   Nothing Specific       Watching Cricket
#
#     Future plan Typically your days are started at:
# 0           NaN                                  NaN
# ...

# %%
data5 = pd.read_excel (r'I:\Pattern Lab\dataset\DATASET_5.xlsx') #for an earlier version of Excel, you may need to use the file extension of 'xls'
data5.head()
# Out:
#             ID Current Place Unnamed: 2 Unnamed: 3 Place of interest  \
# 0          NaN          Name   Latitude  Longitude              Name
# 1  151341008.0       Katasur    40.2824    -79.693         Bandarban
# 2  151341004.0      Lalmatia    23.7571    90.3685       Switzerland
# 3  151341006.0   Mirpur Dohs    23.7073    90.4155         Bandarban
# 4  151341016.0      Banasree    22.5135    88.3015            turkey
#
#   Unnamed: 5 Unnamed: 6 Food you like most Leisure time activity   \
# 0   Latitude  Longitude                NaN                    NaN
# 1   -7.73352    112.959    Kacchi Biriyani               Sleeping
# 2    46.5475    7.98529          Fast Food              Newspaper
# 3    21.8311    92.3686          Fast Food               Sleeping
# 4    38.9637    35.2433       Chinese food                 Gaming
#
#          Future plan Typically your days are started at:
# 0                NaN                                  NaN
# ...

# %%
data6 = pd.read_excel (r'I:\Pattern Lab\dataset\DATASET_6.xlsx') #for an earlier version of Excel, you may need to use the file extension of 'xls'
data6.head()
# Out:
#             ID Current Place Unnamed: 2 Unnamed: 3 Place of interest  \
# 0          NaN          Name   Latitude  Longitude              Name
# 1  151340921.0       Tejgaon    23.7073    90.4155      saint martin
# 2  151340923.0  Siddheshwari    23.7446    90.4115       Cox's Bazar
# 3  151340925.0    Maniknagar    23.7214    90.4299           My Room
# 4  151340926.0    Maniknagar    23.7226    90.4296            Sylhet
#
#   Unnamed: 5 Unnamed: 6 Food you like most           Leisure time activity   \
# 0   Latitude  Longitude                NaN                              NaN
# 1    49.4355   -2.56735          Alu Vorta                     playing game
# 2     21.427    91.9712              Pasta      Watching Movies & TV-Series
# 3    23.7214    90.4299         Cashew nut  Traversing Foreign Universities
# 4    24.8949    91.8687         Cashew nut                      Photography
#
#           Future plan Typically your days are started at:
# ...

# %%
data3.rename(columns={'Place of Interest':'Place of interest', 'Leisure time Activity':'Leisure time activity',
                     'Future Plan':'Future plan'}, inplace=True)

# %%
data4.columns=['ID','Current Place','Unnamed: 2','Unnamed: 3','Place of interest','Unnamed: 5','Unnamed: 6',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
s=pd.concat([data1,data4], ignore_index=True, sort=False)
s.shape
# Out:
# (43, 11)

# %%
data5.columns=['ID','Current Place','Unnamed: 2','Unnamed: 3','Place of interest','Unnamed: 5','Unnamed: 6',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
data6.columns=['ID','Current Place','Unnamed: 2','Unnamed: 3','Place of interest','Unnamed: 5','Unnamed: 6',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
s=pd.concat([data1,data2,data3,data4,data5,data6], ignore_index=True, sort=False)
s.shape
# Out:
# (140, 11)

# %%
s1=pd.merge(df,s)
s1.shape
# Out:
# (103, 81)

# %%
print(s1)
# Out:
#               Timestamp  Score         ID  Gender              Height  Weight  \
# 0    3/23/2019 19:10:21  0 / 2  151341004     NaN                 5.7     NaN
# 1    3/24/2019 14:41:32  0 / 1  151341004    Male               5'6''    70.0
# 2    3/24/2019 14:29:31  0 / 1  151341021    Male                5'3"    61.0
# 3    3/24/2019 14:33:11  0 / 1  151341012    Male                 5.8    78.0
# 4    3/24/2019 14:34:00  0 / 1  151341008  Female                 5.3    48.0
# 5    3/24/2019 14:33:55  0 / 1  151341011    Male             161.544    59.0
# 6    3/24/2019 14:35:07  0 / 1  151341029    Male                5'5"    96.0
# 7    3/24/2019 14:35:08  0 / 1  151341005  Female              4'11''    46.0
# 8    3/24/2019 14:35:16  0 / 1  151341006  Female                 4.1    51.0
# 9    3/24/2019 14:36:29  0 / 1  151341023  Female       5 feet 5 inch    40.0
# 10   3/24/2019 14:39:33  0 / 1  151341009  Female                5'4"    49.0
# ...

# %%
s1.head()
# Out:
#             Timestamp  Score         ID  Gender Height  Weight  CGPA  \
# 0  3/23/2019 19:10:21  0 / 2  151341004     NaN    5.7     NaN   NaN
# 1  3/24/2019 14:41:32  0 / 1  151341004    Male  5'6''    70.0  3.71
# 2  3/24/2019 14:29:31  0 / 1  151341021    Male   5'3"    61.0  3.48
# 3  3/24/2019 14:33:11  0 / 1  151341012    Male    5.8    78.0  2.90
# 4  3/24/2019 14:34:00  0 / 1  151341008  Female    5.3    48.0  3.33
#
#   Daily spent time in social media (hour)    Hometown  \
# 0                                     NaN         NaN
# 1                            Below 1 hour        Feni
# 2                     2019-05-02 00:00:00  Lakshmipur
# 3                            Below 1 hour  Munshiganj
# 4                     2019-05-02 00:00:00    Bagerhat
#
#   How many days in a week you feel more energetic  \
# 0                                             NaN
# 1                                               4
# 2                                               4
# ...

# %%
data1.columns=['ID','Current Place','Latitude cp','Longitude cp','Place of interest','Latitude pi','Longitude pi',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
data2.columns=['ID','Current Place','Latitude cp','Longitude cp','Place of interest','Latitude pi','Longitude pi',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
data3.columns=['ID','Current Place','Latitude cp','Longitude cp','Place of interest','Latitude pi','Longitude pi',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
data4.columns=['ID','Current Place','Latitude cp','Longitude cp','Place of interest','Latitude pi','Longitude pi',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
data5.columns=['ID','Current Place','Latitude cp','Longitude cp','Place of interest','Latitude pi','Longitude pi',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
data6.columns=['ID','Current Place','Latitude cp','Longitude cp','Place of interest','Latitude pi','Longitude pi',
               'Leisure time activity','Food you like most','Future plan','Typically your days are started at:']

# %%
s=pd.concat([data1,data2,data3,data4,data5,data6], ignore_index=True, sort=False)
s.shape
# Out:
# (140, 11)

# %%
s1=pd.merge(df,s)
s1.shape
# Out:
# (103, 81)

# %%
s1.head()
# Out:
#             Timestamp  Score         ID  Gender Height  Weight  CGPA  \
# 0  3/23/2019 19:10:21  0 / 2  151341004     NaN    5.7     NaN   NaN
# 1  3/24/2019 14:41:32  0 / 1  151341004    Male  5'6''    70.0  3.71
# 2  3/24/2019 14:29:31  0 / 1  151341021    Male   5'3"    61.0  3.48
# 3  3/24/2019 14:33:11  0 / 1  151341012    Male    5.8    78.0  2.90
# 4  3/24/2019 14:34:00  0 / 1  151341008  Female    5.3    48.0  3.33
#
#   Daily spent time in social media (hour)    Hometown  \
# 0                                     NaN         NaN
# 1                            Below 1 hour        Feni
# 2                     2019-05-02 00:00:00  Lakshmipur
# 3                            Below 1 hour  Munshiganj
# 4                     2019-05-02 00:00:00    Bagerhat
#
#   How many days in a week you feel more energetic  \
# 0                                             NaN
# 1                                               4
# 2                                               4
# ...

# %%
s1.to_excel('merged.xlsx')

# %%
s2=s.append(s1, ignore_index=True, sort=False)
s2.shape
# Out:
# (243, 81)

# %%
s2=s.append(s1,sort=False)
s2.drop_duplicates(subset=['ID'],keep='last',inplace=True)
s2.shape
# Out:
# (135, 81)

# %%
s2.to_excel('merged and concat.xlsx')

# %%
print(s2)
# Out:
#               ID     Current Place Latitude cp      Longitude cp  \
# 3    151340978.0           Azimpur      23.727           90.3847
# 45   151340949.0          kunipara     20.5383           86.3094
# 46   151340950.0          Khilgaon     23.7073           90.4155
# 47   151340951.0          Matikata     23.8225           90.3935
# 48   151340952.0          Banasree     23.7632           90.4348
# 49   151340954.0            Mirpur     23.8139           90.3663
# 50   151340955.0         Moghbazar      23.741           90.4115
# 51   151340956.0          Malibagh     23.7436           90.4152
# 52   151340957.0        Shewrapara       23.79           90.3666
# 53   151340958.0        Luxmibazar     23.7073           90.4155
# 54   151340959.0        Luxmibazar     23.7073           90.4155
# 55   151340960.0          Banasree     23.7073           90.4155
# 56   151340961.0     Niketon Bazar     23.7439            90.369
# ...

# %%
s2.head()
# Out:
#              ID Current Place Latitude cp Longitude cp Place of interest  \
# 3   151340978.0       Azimpur      23.727      90.3847       Kaptai Lake
# 45  151340949.0      kunipara     20.5383      86.3094         Bandarban
# 46  151340950.0      Khilgaon     23.7073      90.4155         Bandarban
# 47  151340951.0      Matikata     23.8225      90.3935         Bandarban
# 48  151340952.0      Banasree     23.7632      90.4348      Saint Martin
#
#    Latitude pi Longitude pi Leisure time activity   Food you like most  \
# 3      22.7552       92.277        kacchi biryani               Series
# 45     21.8311      92.3686             coldcoffe  Music,reading Quran
# 46     21.8311      92.3686                 Kabab      Watching movies
# 47     21.8311      92.3686        Kacchi Biriany      Watching movies
# 48     20.9232      92.2676         Fish Barbecue              Jogging
#
#                       Future plan  \
# 3   Higher Study in North America
# ...
